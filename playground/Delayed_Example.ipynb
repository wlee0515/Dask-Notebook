# %%
from dask.distributed import Client, progress
client = Client("tcp://scheduler:8786")
client
# Out:
# <Client: 'tcp://172.18.0.6:8786' processes=2 threads=8, memory=0.98 GiB>

# %%
import time
import random

def inc(x):
    time.sleep(2)
    return x + 1

def dec(x):
    time.sleep(2)
    return x - 1
    
def add(x, y):
    time.sleep(2)
    return x + y

# %%
# %%time
x = inc(1)
y = dec(2)
z = add(x, y)
z
# Out:
# CPU times: user 17.6 ms, sys: 0 ns, total: 17.6 ms
# Wall time: 6.01 s
# 3

# %%
import dask

# %%
# %%time
x = dask.delayed(inc)(1)
y = dask.delayed(dec)(2)
z = dask.delayed(add)(x, y)
z.compute()
# Out:
# CPU times: user 163 ms, sys: 33.6 ms, total: 196 ms
# Wall time: 4.53 s
# 3

# %%
# %%time
zs = []
for i in range(40):
    x = dask.delayed(inc)(i)
    y = dask.delayed(dec)(x)
    z = dask.delayed(add)(x, y)
    zs.append(z)
# Out:
# CPU times: user 37.9 ms, sys: 0 ns, total: 37.9 ms
# Wall time: 38.6 ms

# %%
# %%time
zs = dask.persist(*zs)
# Out:
# CPU times: user 25.6 ms, sys: 8.45 ms, total: 34.1 ms
# Wall time: 35.1 ms

# %%
zs
# Out:
# (Delayed('add-800a3005-548a-4cc5-90b7-669e983c3b98'),
#  Delayed('add-095c15df-49b4-4017-9f5a-6f78df880d08'),
#  Delayed('add-b29befda-d40d-4c11-b32e-259337952584'),
#  Delayed('add-3ed31664-6109-4505-ab69-c208433592fa'),
#  Delayed('add-33d3a0b2-c642-47ca-845a-3ecb8247b24d'),
#  Delayed('add-7c70b628-1694-41c2-a8a8-1cf1ba34cb01'),
#  Delayed('add-c2ca77d5-b430-4a1b-b415-9eb3452850db'),
#  Delayed('add-9a775297-2896-4795-8820-6c159da86c3c'),
#  Delayed('add-1c9e2dbf-f370-452d-aaa3-a81e31ac39f1'),
#  Delayed('add-e94dbf6d-e1c0-40dd-a81c-81ac6677bd43'),
#  Delayed('add-60b67065-1a27-4335-b8c1-03535d456c68'),
#  Delayed('add-e5caf91c-f8b5-4d67-b847-d23a005c4d84'),
#  Delayed('add-745a456c-86a8-4df1-bcd8-a1b449984819'),
#  Delayed('add-87bf8cae-e2d5-4680-b1db-2d42c0db24ee'),
#  Delayed('add-bcdbdacb-cd35-4552-88b5-ad2df9ed0aad'),
#  Delayed('add-f2cd31cc-50ae-4a11-91cf-202feceec917'),
#  Delayed('add-4b332e02-17f8-4f42-9066-d9c77f36e62e'),
#  Delayed('add-a3993c8e-d560-477d-9cb9-7e4223789fd1'),
#  Delayed('add-e7fd60dd-9b2e-4c5d-8ab7-112c22b5d4f3'),
#  Delayed('add-81a76041-b543-46e3-b595-f4bdaee3cd57'),
#  Delayed('add-2d47ef02-936d-47e5-a1f3-ec68425b3dae'),
#  Delayed('add-410a20ad-de58-4e7a-bc20-ffb1a154ad91'),
#  Delayed('add-25222d0c-0fd9-4ea7-8abd-48ec23d3a632'),
#  Delayed('add-222c9e18-406a-4370-afc5-e57243437397'),
#  Delayed('add-63e23426-3d26-4a9c-a452-aecb69da327c'),
#  Delayed('add-75e8187e-8bd1-4868-b9fd-51626075bef7'),
#  Delayed('add-d223eaab-cb4d-4fa5-9e46-e14520c5697b'),
#  Delayed('add-9774c634-0082-4596-a1fc-4d4edc911d6d'),
#  Delayed('add-39685a3b-a5d7-45c6-b408-0d3b5267986a'),
#  Delayed('add-424f5264-cbea-4b61-8466-c5bb3c6bb8e6'),
#  Delayed('add-27ca05e5-5e39-4bf8-9970-a9b0f7cfc6ae'),
#  Delayed('add-f0fc6ba8-4369-458d-9cf9-0e332f2b94ea'),
#  Delayed('add-04674512-ec5e-4f2f-a4df-b81641e5f871'),
#  Delayed('add-b6f341f0-1ae7-4e5a-972b-c07f30be2ec6'),
#  Delayed('add-f0a6ba40-2744-43e3-879c-bc9923458cc1'),
#  Delayed('add-ccdbd74a-4430-4677-b516-a0ac117d9e8d'),
#  Delayed('add-1e0340c0-75d2-488b-9593-e00f30d09274'),
#  Delayed('add-480dd3ca-a039-4310-809a-62a2726ab999'),
#  Delayed('add-2df7051a-77f7-4249-9c23-c1f91d599bd2'),
#  Delayed('add-408c36b3-0fc5-4d24-ba2c-dd9c6663c7fc'))
